# %%
from proxy_sim import Simulator
print(Simulator(arrival_rate=10, service_rate=20, duration=10000, seed=42).run())
# Out:
# {'arrival_rate': 10, 'service_rate': 20, 'num_backends': 1, 'duration': 9999.926350806012, 'completed': 99943, 'rejected': 0, 'throughput_rps': 9.994373607756062, 'mean_latency': 0.09932882614082315, 'p50_latency': 0.06870214582704648, 'p95_latency': 0.29841097994457466, 'p99_latency': 0.46173572804972585}
